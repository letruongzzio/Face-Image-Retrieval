# %%
from lib.prepare import download_data

path = download_data()

# %%
# !ls $path
# Out:
# img_align_celeba      list_bbox_celeba.csv     list_landmarks_align_celeba.csv
# list_attr_celeba.csv  list_eval_partition.csv

# %%
from os.path import join

image_dir_path = join(path, "img_align_celeba", "img_align_celeba")

# %%
import cv2 as cv
import matplotlib.pyplot as plt

image = cv.imread(join(image_dir_path, "100000.jpg"))
plt.imshow(cv.cvtColor(image, cv.COLOR_BGR2RGB))

# %%
image.shape
# Out:
# (218, 178, 3)

# %%
from lib.processing import crop_face

state, face = crop_face(image, 1.12, 9)
if state == "one":
    cv.imwrite("./test.png", face)
